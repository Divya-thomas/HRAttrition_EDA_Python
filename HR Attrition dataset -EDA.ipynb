# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import os

# %%
#Setting the default seaborn stype for plots
sns.set()

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Divya\\Desktop\\PGBABI\\GLPython\\Attritiondataset'

# %%
##os.chdir('C:\\Users\Divya\Desktop\PGBABI\GLPython\Attritiondataset')

# %%
df=pd.read_csv('HR_Employee_Attrition_new.csv')

# %%
df.head()
# Out:
#    Age Attrition     BusinessTravel              Department  DistanceFromHome  \
# 0   41       Yes      Travel_Rarely                   Sales                 1
# 1   49        No  Travel_Frequently  Research & Development                 8
# 2   37       Yes      Travel_Rarely  Research & Development                 2
# 3   33        No  Travel_Frequently  Research & Development                 3
# 4   27        No      Travel_Rarely  Research & Development                 2
#
#    Education EducationField  EmployeeNumber  Gender  HourlyRate  ... OverTime  \
# 0          2  Life Sciences               1  Female          94  ...      Yes
# 1          1  Life Sciences               2    Male          61  ...       No
# 2          2          Other               4    Male          92  ...      Yes
# 3          4  Life Sciences               5  Female          56  ...      Yes
# 4          1        Medical               7    Male          40  ...       No
#
# ...

# %%
df.tail()
# Out:
#       Age Attrition     BusinessTravel              Department  \
# 1465   36        No  Travel_Frequently  Research & Development
# 1466   39        No      Travel_Rarely  Research & Development
# 1467   27        No      Travel_Rarely  Research & Development
# 1468   49        No  Travel_Frequently                   Sales
# 1469   34        No      Travel_Rarely  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeNumber Gender  \
# 1465                23          2        Medical            2061   Male
# 1466                 6          1        Medical            2062   Male
# 1467                 4          3  Life Sciences            2064   Male
# 1468                 2          3        Medical            2065   Male
# 1469                 8          3        Medical            2068   Male
#
#       HourlyRate  ... OverTime  PercentSalaryHike PerformanceRating  \
# 1465          41  ...       No                 17                 3
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 25 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Age                      1470 non-null   int64
#  1   Attrition                1470 non-null   object
#  2   BusinessTravel           1470 non-null   object
#  3   Department               1470 non-null   object
#  4   DistanceFromHome         1470 non-null   int64
#  5   Education                1470 non-null   int64
#  6   EducationField           1470 non-null   object
#  7   EmployeeNumber           1470 non-null   int64
#  8   Gender                   1470 non-null   object
#  9   HourlyRate               1470 non-null   int64
#  10  JobRole                  1470 non-null   object
#  11  JobSatisfaction          1470 non-null   int64
#  12  MaritalStatus            1470 non-null   object
#  13  MonthlyIncome            1470 non-null   int64
# ...

# %%
df.describe()
# Out:
#                Age  DistanceFromHome    Education  EmployeeNumber  \
# count  1470.000000       1470.000000  1470.000000     1470.000000
# mean     36.923810          9.192517     2.912925     1024.865306
# std       9.135373          8.106864     1.024165      602.024335
# min      18.000000          1.000000     1.000000        1.000000
# 25%      30.000000          2.000000     2.000000      491.250000
# 50%      36.000000          7.000000     3.000000     1020.500000
# 75%      43.000000         14.000000     4.000000     1555.750000
# max      60.000000         29.000000     5.000000     2068.000000
#
#         HourlyRate  JobSatisfaction  MonthlyIncome  NumCompaniesWorked  \
# count  1470.000000      1470.000000    1470.000000         1470.000000
# mean     65.891156         2.728571    6502.931293            2.693197
# std      20.329428         1.102846    4707.956783            2.498009
# min      30.000000         1.000000    1009.000000            0.000000
# ...

# %%
df.describe().T
# Out:
#                           count         mean          std     min      25%  \
# Age                      1470.0    36.923810     9.135373    18.0    30.00
# DistanceFromHome         1470.0     9.192517     8.106864     1.0     2.00
# Education                1470.0     2.912925     1.024165     1.0     2.00
# EmployeeNumber           1470.0  1024.865306   602.024335     1.0   491.25
# HourlyRate               1470.0    65.891156    20.329428    30.0    48.00
# JobSatisfaction          1470.0     2.728571     1.102846     1.0     2.00
# MonthlyIncome            1470.0  6502.931293  4707.956783  1009.0  2911.00
# NumCompaniesWorked       1470.0     2.693197     2.498009     0.0     1.00
# PercentSalaryHike        1470.0    15.209524     3.659938    11.0    12.00
# PerformanceRating        1470.0     3.153741     0.360824     3.0     3.00
# TotalWorkingYears        1470.0    11.279592     7.780782     0.0     6.00
# ...

# %%
df.describe(include='all').T
# Out:
#                         count unique                     top  freq     mean  \
# Age                      1470    NaN                     NaN   NaN  36.9238
# Attrition                1470      2                      No  1233      NaN
# BusinessTravel           1470      3           Travel_Rarely  1043      NaN
# Department               1470      3  Research & Development   961      NaN
# DistanceFromHome         1470    NaN                     NaN   NaN  9.19252
# Education                1470    NaN                     NaN   NaN  2.91293
# EducationField           1470      6           Life Sciences   606      NaN
# EmployeeNumber           1470    NaN                     NaN   NaN  1024.87
# Gender                   1470      2                    Male   882      NaN
# HourlyRate               1470    NaN                     NaN   NaN  65.8912
# JobRole                  1470      9         Sales Executive   326      NaN
# ...

# %%
df.EnvironmentSatisfaction=df.EnvironmentSatisfaction.astype('object')
df.JobSatisfaction=df.JobSatisfaction.astype('object')
df.PerformanceRating=df.PerformanceRating.astype("object")
df.WorkLifeBalance=df.WorkLifeBalance.astype('object')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-13-a0f93142b786> in <module>
# ----> 1 df.EnvironmentSatisfaction=df.EnvironmentSatisfaction.astype('object')
#       2 df.JobSatisfaction=df.JobSatisfaction.astype('object')
#       3 df.PerformanceRating=df.PerformanceRating.astype("object")
#       4 df.WorkLifeBalance=df.WorkLifeBalance.astype('object')
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'EnvironmentSatisfaction'

# %%
df.info()

# %%
df.isnull().sum().sum()

# %%
df.PerformanceRating.value_counts()

# %%
df.PerformanceRating.mode()

# %%
df.PerformanceRating.mode()[0]

# %%
#df.PerformanceRating.fillna(df['PerformanceRating'].mode()[0],inplace=True)

# %%
df.HourlyRate.describe()

# %%
sns.boxplot(x='HourlyRate',data=df)

# %%
#df.HourlyRate.fillna(df['HourlyRate'].mean(),inplace=True)

# %%
df.info()

# %%
df.isnull().sum().sum()

# %%
df.shape

# %%
df.Department.value_counts(normalize=True)

# %%
df.Attrition.value_counts(normalize=True)

# %%
df.head(2)

# %%
df.Age.describe()

# %%
df.EducationField.value_counts(normalize=True)

# %%
fig,ax=plt.subplots(nrows=1,ncols=2,figsize=(10,5))
sns.distplot(df.Age,kde=True,ax=ax[0])
sns.boxplot(x='Age',data=df,ax=ax[1])

# %%
df.MonthlyIncome.describe()

# %%
fig,ax=plt.subplots(nrows=1,ncols=2,figsize=(10,5))
sns.distplot(df.MonthlyIncome,kde=False,rug=True,ax=ax[0])
sns.boxplot(x='MonthlyIncome',data=df,ax=ax[1])

# %%
#ategorical Information
def univariate_category(cat_column):
    print("Details of "+cat_column)
    print("-------")
    print(df[cat_column].value_counts())
    sns.countplot(x=cat_column,data=df,palette='pastel')
    plt.show()
    print("    ")

# %%
#Pick th categorical columns
df_object=df.select_dtypes(include=['object'])
lstcatcolumns=list(df_object.columns.values)
lstcatcolumns

# %%
for x in lstcatcolumns:
    univariate_category(x)

# %%
sns.catplot(y='JobRole',kind='count',aspect=2,data=df)

# %%
ax=sns.countplot(x='EducationField',data=df)
ax.set_xticklabels(ax.get_xticklabels(),rotation=40,ha='right')

# %%
#Bivariate
sns.pairplot(df)

# %%
sns.pairplot(df,corner=True,diag_kind='kde')

# %%
fig,ax=plt.subplots(nrows=1,ncols=2,figsize=(10,5))
sns.scatterplot(x="Age",y="MonthlyIncome",data=df,ax=ax[0])
sns.scatterplot(x="TotalWorkingYears",y="MonthlyIncome",data=df,ax=ax[1])

# %%
cor=df.corr()
round(cor,2)
# Out:
#                           Age  DistanceFromHome  Education  EmployeeNumber  \
# Age                      1.00             -0.00       0.21           -0.01
# DistanceFromHome        -0.00              1.00       0.02            0.03
# Education                0.21              0.02       1.00            0.04
# EmployeeNumber          -0.01              0.03       0.04            1.00
# HourlyRate               0.02              0.03       0.02            0.04
# JobSatisfaction         -0.00             -0.00      -0.01           -0.05
# MonthlyIncome            0.50             -0.02       0.09           -0.01
# NumCompaniesWorked       0.30             -0.03       0.13           -0.00
# PercentSalaryHike        0.00              0.04      -0.01           -0.01
# PerformanceRating        0.00              0.03      -0.02           -0.02
# TotalWorkingYears        0.68              0.00       0.15           -0.01
# ...

# %%
fig=plt.subplots(figsize=(10,6))
sns.set(font_scale=1.0)
sns.heatmap(round(cor,2),annot=True,mask=(np.triu(cor,+1)))

# %%
#cat with cat
sns.countplot(x='Attrition',hue='Gender',data=df)

# %%
sns.countplot(y='OverTime',hue='Attrition',data=df)

# %%
#crosstab
pd.crosstab(df.Attrition,df.EducationField,normalize='columns')
# Out:
# EducationField  Human Resources  Life Sciences  Marketing   Medical     Other  \
# Attrition
# No                     0.740741       0.853135   0.779874  0.864224  0.865854
# Yes                    0.259259       0.146865   0.220126  0.135776  0.134146
#
# EducationField  Technical Degree
# Attrition
# No                      0.757576
# Yes                     0.242424

# %%
pd.crosstab(df.Attrition,df.EducationField,normalize='columns',margins=True)
# Out:
# EducationField  Human Resources  Life Sciences  Marketing   Medical     Other  \
# Attrition
# No                     0.740741       0.853135   0.779874  0.864224  0.865854
# Yes                    0.259259       0.146865   0.220126  0.135776  0.134146
#
# EducationField  Technical Degree       All
# Attrition
# No                      0.757576  0.838776
# Yes                     0.242424  0.161224

# %%
pd.crosstab(df.Attrition,df.EducationField,normalize=True,margins=True)
# Out:
# EducationField  Human Resources  Life Sciences  Marketing   Medical     Other  \
# Attrition
# No                     0.013605       0.351701   0.084354  0.272789  0.048299
# Yes                    0.004762       0.060544   0.023810  0.042857  0.007483
# All                    0.018367       0.412245   0.108163  0.315646  0.055782
#
# EducationField  Technical Degree       All
# Attrition
# No                      0.068027  0.838776
# Yes                     0.021769  0.161224
# All                     0.089796  1.000000

# %%
pd.crosstab(df.Attrition,df.JobSatisfaction)
# Out:
# JobSatisfaction    1    2    3    4
# Attrition
# No               223  234  369  407
# Yes               66   46   73   52

# %%
#cat and num
fig,ax=plt.subplots(nrows=1,ncols=3,figsize=(12,5))
sns.boxplot(x='Attrition',y='MonthlyIncome',data=df,ax=ax[0])
sns.boxplot(x='Attrition',y='Age',data=df,ax=ax[1])
sns.boxplot(x='Attrition',y='DistanceFromHome',data=df,ax=ax[2])

# %%
#Multivariate
fig,ax=plt.subplots(figsize=(12,6))
sns.scatterplot(x='NumCompaniesWorked',y='TotalWorkingYears',hue='Attrition',data=df)

# %%
#Multivariate
fig,ax=plt.subplots(figsize=(12,6))
sns.boxplot(x='Attrition',y='YearsAtCompany',hue='BusinessTravel',data=df)

# %%
#FacetGrid
g=sns.FacetGrid(df,col='JobRole',hue='Attrition',col_wrap=3,height=3)
g=g.map(plt.scatter,"YearsSinceLastPromotion",'YearsAtCompany')

# %%
cont=df.dtypes[(df.dtypes!='object')].index
plt.figure(figsize=(10,10))
df[cont].boxplot(vert=0)
plt.title('With Outliers',fontsize=16)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
#Remove outliers

def remove_outliers(col):
    sorted(col)
    Q1,Q3=np.percentile(col,[25,75])
    IQR=Q3-Q1
    lower_range=Q1-(1.5*IQR)
    upper_range=Q3+(1.5*IQR)
    return lower_range,upper_range

# %%
for column in df[cont].columns:
    lr,ur=remove_outliers(df[column])
    df[column]=np.where(df[column]>ur,ur,df[column])
    df[column]=np.where(df[column]<lr,lr,df[column])

# %%
cont=df.dtypes[(df.dtypes!='object')].index
plt.figure(figsize=(10,10))
df[cont].boxplot(vert=0)
plt.title('With Outliers',fontsize=16)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>
